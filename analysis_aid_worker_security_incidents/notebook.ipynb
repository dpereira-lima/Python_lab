# %% [markdown]
# # Graphical and exploratory analysis

# %% [markdown]
# ## of the Aid Worker Security Incidents data set
# ## from the website: https://data.world/makeovermonday/2024w46-aid-worker-security-incidents

# %%
# import from libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# read dataset

df = pd.read_excel('https://query.data.world/s/p6vgvdqvpghtq267f46nipcugrthnz?dws=00000')

# %% [markdown]
# ## first analysis

# %%
df.head()
# Out:
#    Incident ID  Year  Month  Day Country Code     Country            Region  \
# 0           35  1997    NaN  NaN          NaN         NaN               NaN
# 1            1  1997    1.0  NaN           KH    Cambodia  Banteay Meanchey
# 2            2  1997    1.0  NaN           RW      Rwanda          Northern
# 3            3  1997    2.0  NaN           TJ  Tajikistan               NaN
# 4            4  1997    2.0  NaN           SO     Somalia        Lower Juba
#
#   District       City  UN  ...  Attack context         Location   Latitude  \
# 0      NaN        NaN   0  ...         Unknown          Unknown        NaN
# 1      NaN        NaN   0  ...         Unknown          Unknown  14.070929
# 2  Musanze  Ruhengeri   0  ...            Raid  Office/compound  -1.499840
# 3      NaN        NaN   4  ...         Unknown          Unknown  38.628173
# 4  Kismayo    Kismayo   0  ...         Unknown          Unknown  -0.358216
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Incident ID               4153 non-null   int64
#  1   Year                      4153 non-null   int64
#  2   Month                     4104 non-null   float64
#  3   Day                       3810 non-null   float64
#  4   Country Code              4119 non-null   object
#  5   Country                   4147 non-null   object
#  6   Region                    3788 non-null   object
#  7   District                  3435 non-null   object
#  8   City                      3190 non-null   object
#  9   UN                        4153 non-null   int64
#  10  INGO                      4153 non-null   int64
#  11  ICRC                      4144 non-null   float64
#  12  NRCS and IFRC             4144 non-null   float64
# ...
